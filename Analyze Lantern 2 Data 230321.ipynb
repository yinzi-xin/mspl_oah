# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from astropy.io import fits
from hcipy import *
from scipy import ndimage
from scipy import fft
from oah_tools import *

# %%
bkgd = fits.getdata('lant2_data_230321/bkgd_0.9968710000000001_avgs100.fits')
ref = fits.getdata('lant2_data_230321/ref_0.9968710000000001_avgs100.fits')-bkgd

lp01_holo = fits.getdata('lant2_data_230321/lp01_holo_0.9968710000000001_avgs1.fits')-bkgd
lp11a_holo = fits.getdata('lant2_data_230321/lp11a_holo_0.9968710000000001_avgs1.fits')-bkgd
lp11b_holo = fits.getdata('lant2_data_230321/lp11b_holo_0.9968710000000001_avgs1.fits')-bkgd
lp21a_holo = fits.getdata('lant2_data_230321/lp21a_holo_0.9968710000000001_avgs1.fits')-bkgd
lp21b_holo = fits.getdata('lant2_data_230321/lp21b_holo_0.9968710000000001_avgs1.fits')-bkgd
lp02_holo = fits.getdata('lant2_data_230321/lp02_holo_0.9968710000000001_avgs1.fits')-bkgd

centerx = 252
centery = 303
crop_width = 495

lp01_crop = lp01_holo[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]
lp11a_crop = lp11a_holo[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]
lp11b_crop = lp11b_holo[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]
lp21a_crop = lp21a_holo[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]
lp21b_crop = lp21b_holo[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]
lp02_crop = lp02_holo[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]
ref_crop = ref[int(centerx-crop_width/2):int(centerx+crop_width/2),int(centery-crop_width/2):int(centery+crop_width/2)]

print(lp01_crop.shape)
plt.imshow(lp21a_crop,vmin=0)
# Out:
# (495, 495)

# %%
recon_map_extent = 101

grid = make_uniform_grid([recon_map_extent,recon_map_extent], [recon_map_extent,recon_map_extent])

lp_modes = make_lp_modes(grid, 5, 30)

x_starts = 85.5
y_starts = 284

x1s = np.linspace(x_starts-2,x_starts+2,11)
y1s = np.linspace(y_starts-2,y_starts+2,11)

holos = [lp01_crop,lp11a_crop,lp11b_crop,lp21a_crop,lp21b_crop,lp02_crop]

ret_fields = []
plt.figure()
for n in range(len(holos)):
    best_x,best_y = optimize_shift_location(holos[n],ref_crop,x1s,y1s,57,lp_modes,n)
    ret_field=retrieve_mode_lant(holos[n],ref_crop,x1=best_x,y1=best_y,box_width=57)
    ret_fields.append(ret_field)
    plt.subplot(2,3,n+1)
    imshow_field(ret_field)
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21679/2195040181.py in <module>
#      16 plt.figure()
#      17 for n in range(len(holos)):
# ---> 18     best_x,best_y = optimize_shift_location(holos[n],ref_crop,x1s,y1s,57,lp_modes,n)
#      19     ret_field=retrieve_mode_lant(holos[n],ref_crop,x1=best_x,y1=best_y,box_width=57)
#      20     ret_fields.append(ret_field)
#
# ~/yxin/holography/oah_tools.py in optimize_shift_location(holo, ref, x1s, y1s, box_width, lp_modes, mode_num)
#      91     for n in range(len(x1s)):
#      92         for m in range(len(y1s)):
# ---> 93             recon_map_field = retrieve_mode(holo,ref,x1s[n],y1s[m],box_width)
#      94             shift_coeffs[n,m] = np.abs(np.nansum(np.conj(lp_modes[mode_num])*recon_map_field,axis=None)/np.nansum(np.conj(lp_modes[mode_num])*lp_modes[mode_num],axis=None))
#      95
#
# ~/yxin/holography/oah_tools.py in retrieve_mode(holo, ref, x1, y1, box_width, plot_fig)
#      29     filter_ft = np.zeros(fft_holo.shape)
#      30     filter_ft[xmid,ymid]=1
# ---> 31     fftgram_filt = ndimage.gaussian_filter(filter_ft, 19)*fftgram_filt
#      32
#      33     recon_map_large = np.fft.ifftshift(np.fft.ifft2(np.fft.fftshift(fftgram_filt)))/np.sqrt(ref)
#
# ~/anaconda3/envs/3.7/lib/python3.7/site-packages/scipy/ndimage/filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     341         for axis, sigma, order, mode in axes:
#     342             gaussian_filter1d(input, sigma, axis, order, output,
# --> 343                               mode, cval, truncate)
#     344             input = output
#     345     else:
#
# ~/anaconda3/envs/3.7/lib/python3.7/site-packages/scipy/ndimage/filters.py in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     259     # Since we are calling correlate, not convolve, revert the kernel
#     260     weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 261     return correlate1d(input, weights, axis, output, mode, cval, 0)
#     262
#     263
#
# ~/anaconda3/envs/3.7/lib/python3.7/site-packages/scipy/ndimage/filters.py in correlate1d(input, weights, axis, output, mode, cval, origin)
#     132     mode = _ni_support._extend_mode_to_code(mode)
#     133     _nd_image.correlate1d(input, weights, axis, output, mode, cval,
# --> 134                           origin)
#     135     return output
#     136
#
# KeyboardInterrupt:

# %%
lp21b_ret = ret_fields[0]
recon_map = lp21b_ret.shaped

max_coeffs = []
best_rs = []
radii = np.linspace(25,35,21)
for n in range(len(ret_fields)):
    rotated_field, rot_angle, max_coeff = rotate_mode_to_max(ret_fields[n],lp_modes[n],plot=False)
    best_r = find_r(rotated_field,radii,lp_mode=n,V_num=5)
    best_rs.append(best_r)
    lp_modes = make_lp_modes(grid, 5, best_r)
    
    cur_mode = lp_modes[n]
    
    best_coeff = np.abs(np.nansum(np.conj(cur_mode)*rotated_field,axis=None)/np.nansum(np.conj(cur_mode)*cur_mode,axis=None))
    
    max_coeffs.append(best_coeff)

    plt.figure()
    plt.subplot(1,2,1)
    imshow_field(rotated_field)
    plt.title('Coeff: '+ str(best_coeff))
    plt.subplot(1,2,2)
    imshow_field(lp_modes[n])
    plt.title('Best r: '+str(best_r))
    
lp_modes = make_lp_modes(grid, 5, 31)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_21679/3644957114.py in <module>
# ----> 1 lp21b_ret = ret_fields[0]
#       2 recon_map = lp21b_ret.shaped
#       3
#       4 grid = make_uniform_grid([recon_map.shape[0],recon_map.shape[1]], [recon_map.shape[0],recon_map.shape[1]])
#       5
#
# IndexError: list index out of range
